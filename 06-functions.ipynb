# %%
def celsius_to_kelvin(temp):
    return temp+273.15

# %%
print('freezing point of water', celsius_to_kelvin(0))
print('boiling point of water', celsius_to_kelvin(100))
# Out:
# freezing point of water 273.15
# boiling point of water 373.15

# %%
def fahr_to_celsius(temp):
    return (temp - 32)*(5/9)

# %%
print('this is cold', fahr_to_celsius(0))
# Out:
# this is cold -17.77777777777778

# %%
def fahr_to_kelvin(temp):
    return celcius_to_kelvin(fahr_to_celcius(temp))

# %%
def analyse(filename):
    data = np.loadtxt(fname=filename, delimiter=',')
    fig = plt.figure(figsize=(10,3))

    axes1 = fig.add_subplot(1, 3, 1)
    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))
    axes2 = fig.add_subplot(1, 3, 2)
    axes2.set_ylabel('max')

    axes2.plot(data.max(axis=0))
    axes3 = fig.add_subplot(1, 3, 3)
    axes3.set_ylabel('min')
    axes3.set_ylim(0,6)
    axes3.plot(data.min(axis=0))
    fig.tight_layout()
    plt.show()

# %%
def detect_problems(filename):
    data = np.loadtxt(fname=filename, delimiter=',')
    if data.max(axis=0)[0] == 0 and  data.max(axis=0)[20] == 20:
        print('suspicipous lookin maxxima')
    elif data.min(axis=0).sum() == 0:
        print('minima add up to zero!')
    else:
        print('seems ok')

# %%
import glob

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
filenames= sorted(glob.glob('data/inflammation*.csv'))

# %%
for file_i in filenames:
    print(file_i)
    analyse(file_i)
    detect_problems(file_i)
# Out:
# data\inflammation-01.csv
# suspicipous lookin maxxima
# data\inflammation-02.csv
# suspicipous lookin maxxima
# data\inflammation-03.csv
# minima add up to zero!
# data\inflammation-04.csv
# suspicipous lookin maxxima
# data\inflammation-05.csv
# suspicipous lookin maxxima
# data\inflammation-06.csv
# suspicipous lookin maxxima
# data\inflammation-07.csv
# suspicipous lookin maxxima
# data\inflammation-08.csv
# minima add up to zero!
# data\inflammation-09.csv
# suspicipous lookin maxxima
# data\inflammation-10.csv
# suspicipous lookin maxxima
# data\inflammation-11.csv
# minima add up to zero!
# data\inflammation-12.csv
# suspicipous lookin maxxima

# %%
min?
# Out:
# Docstring:
# min(iterable, *[, default=obj, key=func]) -> value
# min(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its smallest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more arguments, return the smallest argument.
# Type:      builtin_function_or_method

# %%
def celcius_to_kelvin(temp):
    """
    function to change celcius to kelvin
    """
    return temp + 273.15

# %%
celcius_to_kelvin?
# Out:
# Signature: celcius_to_kelvin(temp)
# Docstring: function to change celcius to kelvin
# File:      c:\users\user\desktop\learningpython\<ipython-input-17-4f35beeaed5b>
# Type:      function

# %%
def display(a,b,c):
    print('a:',a,'b:',b,'c:',c)

# %%
display(1,2,3)
# Out:
# a: 1 b: 2 c: 3

# %%
display(a=1,b=2,c=3)
# Out:
# a: 1 b: 2 c: 3

# %%
def display(a,b=0,c=-1):
    print('a:',a,'b:',b,'c:',c)

# %%
display(3)
# Out:
# a: 3 b: 0 c: -1
